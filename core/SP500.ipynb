# %%
from market import SP500

# %%
sp500 = SP500()

# %%
sp500.get_store_tables()
# Out:
# ['/info', '/web']

# %%
sp500.get_table_header('info')
# Out:
# ['symbol',
#  'security_name',
#  'gcis_sector',
#  'gcis_subsector',
#  'hq_address',
#  'date_added',
#  'cik']

# %%
sp500.get_table_header('web')
# Out:
# ['symbol', 'wikipedia', 'website', 'twitter']

# %%
sp500.get_table('info')
# Out:
#     symbol                        security_name             gcis_sector                                gcis_subsector                     hq_address  date_added         cik
# 0      MMM                           3M Company             Industrials                      Industrial Conglomerates            St. Paul, Minnesota              0000066740
# 1      ABT                  Abbott Laboratories             Health Care                         Health Care Equipment        North Chicago, Illinois  1964-03-31  0000001800
# 2     ABBV                          AbbVie Inc.             Health Care                               Pharmaceuticals        North Chicago, Illinois  2012-12-31  0001551152
# 3      ACN                        Accenture plc  Information Technology                IT Consulting & Other Services                Dublin, Ireland  2011-07-06  0001467373
# ...

# %%
sp500.get_table('web')
# Out:
#     symbol                                          wikipedia                              website                               twitter
# 0      MMM                    http://en.wikipedia.org/wiki/3M                    http://www.3m.com                https://twitter.com/3M
# 1      ABT   http://en.wikipedia.org/wiki/Abbott_Laboratories                http://www.abbott.com      https://twitter.com/abbottglobal
# 2     ABBV           http://en.wikipedia.org/wiki/AbbVie_Inc.                    http://abbvie.com            https://twitter.com/abbvie
# 3      ACN         http://en.wikipedia.org/wiki/Accenture_plc            http://www.accenture.com/   https://twitter.com/Accenturecanada
# 4     ATVI   http://en.wikipedia.org/wiki/Activision_Blizzard   http://www.activisionblizzard.com/          https://twitter.com/@ATVI_AB
# 5      AYI     http://en.wikipedia.org/wiki/Acuity_Brands_Inc          http://www.acuitybrands.com      https://twitter.com/acuitybrands
# ...

# %%
sp500.get_sectors()
# Out:
# ['Industrials',
#  'Health Care',
#  'Information Technology',
#  'Consumer Discretionary',
#  'Utilities',
#  'Financials',
#  'Materials',
#  'Real Estate',
#  'Consumer Staples',
#  'Energy',
#  'Telecommunication Services']

# %%
sp500.get_tickers_by_sectors(['Energy'])
# Out:
#     symbol                security_name gcis_sector                      gcis_subsector                           hq_address  date_added         cik
# 42     APC      Anadarko Petroleum Corp      Energy  Oil & Gas Exploration & Production                 The Woodlands, Texas              0000773910
# 44    ANDV                     Andeavor      Energy      Oil & Gas Refining & Marketing                   San Antonio, Texas  2007-09-27  0000050104
# 49     APA           Apache Corporation      Energy  Oil & Gas Exploration & Production                       Houston, Texas              0000006769
# 63    BHGE   Baker Hughes, a GE Company      Energy      Oil & Gas Equipment & Services                       Houston, Texas              0001701605
# 86     COG              Cabot Oil & Gas      Energy  Oil & Gas Exploration & Production                       Houston, Texas  2008-06-23  0000858470
# ...

# %%
sp500.get_ticker_stocks('WMB','2016','2017')
# Out:
#      ticker       date    open     high      low  close      volume  ex-dividend  split_ratio   adj_open   adj_high    adj_low  adj_close  adj_volume
# None
# 0       WMB 2016-01-04  25.520  26.5900  25.3200  26.24  10992721.0          0.0          1.0  22.822158  23.779043  22.643301  23.466043  10992721.0
# 1       WMB 2016-01-05  26.410  26.6800  25.9100  26.33  12394345.0          0.0          1.0  23.618072  23.859529  23.170929  23.546529  12394345.0
# 2       WMB 2016-01-06  25.540  25.7400  22.9000  22.90  16953314.0          0.0          1.0  22.840044  23.018901  20.479131  20.479131  16953314.0
# 3       WMB 2016-01-07  22.210  22.8000  20.6000  20.61  12548917.0          0.0          1.0  19.862074  20.389702  18.422275  18.431218  12548917.0
# 4       WMB 2016-01-08  21.060  21.2276  19.4700  20.31  18822012.0          0.0          1.0  18.833646  18.983528  17.411733  18.162932  18822012.0
# ...
